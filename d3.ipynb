# %% [markdown]
# <a href="https://colab.research.google.com/github/ericyeh-arch/115016_test/blob/main/d3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("abc")
# Out:
# abc
